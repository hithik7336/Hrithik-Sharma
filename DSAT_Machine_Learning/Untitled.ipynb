# %%
import numpy as np

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
path = r'E:\Machine-Learning-Reference-master\Machine-Learning-Reference-master\Machine Learning\1. Supervised Learning\1. Regression\1. Simple Linear Regression\Code\Salary_Data.csv'

# %%
data = pd.read_csv(path)

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x='YearsExperience', y='Salary',data = data)

# %%
X = data.iloc[:,:1]
y = data.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1234)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 55215.41387247,  61968.02151252,  45568.83152956,  36886.90742093,
#        123706.14850718,  55215.41387247])

# %%
lr.intercept_
# Out:
# 24346.350375141083

# %%
lr.coef_
# Out:
# array([9646.58234292])

# %%
y_test
# Out:
# 7      54445.0
# 10     63218.0
# 4      39891.0
# 1      46205.0
# 28    122391.0
# 8      64445.0
# Name: Salary, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9526132681833809

# %%
df = pd.read_csv(r'E:\Machine-Learning-Reference-master\Machine-Learning-Reference-master\Machine Learning\1. Supervised Learning\1. Regression\2. Multilinear Regression\Codes\50_Startups.csv')

# %%
df
# Out:
#     RnD Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
pd.get_dummies(df['State'])
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...
